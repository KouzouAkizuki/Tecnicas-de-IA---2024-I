# %%
from Functions import *

a = getHand('/Images/Indoor_G.jpg')
b = getHand('/Images/Pattern_G.jpg')
c = getHand('/Images/Green_G.jpg')
# Out:
# 159.80071877777777
# 125.42135955555555
# 103.66181344444445

# %%
plt.subplot(1,3,1), plt.imshow(a ,cmap=plt.cm.gray), plt.title('a ', fontsize = 10)
plt.axis('off')
plt.subplot(1,3,2), plt.imshow(b ,cmap=plt.cm.gray), plt.title('b ', fontsize = 10)
plt.axis('off')
plt.subplot(1,3,3), plt.imshow(c ,cmap=plt.cm.gray), plt.title('c ', fontsize = 10)
plt.axis('off')

plt.subplots_adjust(top=1, bottom=0, left=0, right=2, hspace=0.5, wspace=-0.5)
plt.show()
